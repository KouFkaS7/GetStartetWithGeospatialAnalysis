# %% [markdown]
# <a href="https://colab.research.google.com/github/KouFkaS7/GetStartetWithGeospatialAnalysis/blob/main/Geospatial_Analysis_With_Python.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import geopandas as gpd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
municipality = gpd.read_file('/municipality.shp')

# %%
municipality.geojson = ('/municipality.geojson')

# %%
#length of a file
len(municipality)
# Out:
# 775

# %%
municipality.head()
# Out:
#    PROVINCE        PR_NAME   DISTRICT           PALIKA        TYPE  \
# 0         1  Province No 1  TAPLEJUNG  Aathrai Tribeni  Gaunpalika
# 1         1  Province No 1  TAPLEJUNG       Maiwakhola  Gaunpalika
# 2         1  Province No 1  TAPLEJUNG        Meringden  Gaunpalika
# 3         1  Province No 1  TAPLEJUNG       Mikwakhola  Gaunpalika
# 4         1  Province No 1  TAPLEJUNG     Phaktanglung  Gaunpalika
#
#                                             geometry
# 0  POLYGON ((87.60985 27.37043, 87.61107 27.36943...
# 1  POLYGON ((87.50402 27.42901, 87.50672 27.42831...
# 2  POLYGON ((87.51233 27.56818, 87.51196 27.56768...
# 3  POLYGON ((87.66620 27.73004, 87.66659 27.73000...
# 4  POLYGON ((87.83673 27.95137, 87.83735 27.95119...

# %%
municipality.geom_type
# Out:
# 0      Polygon
# 1      Polygon
# 2      Polygon
# 3      Polygon
# 4      Polygon
#         ...
# 770    Polygon
# 771    Polygon
# 772    Polygon
# 773    Polygon
# 774    Polygon
# Length: 775, dtype: object

# %%
type(municipality)
# Out:
# geopandas.geodataframe.GeoDataFrame

# %%
municipality.crs
# Out:
# <Geographic 2D CRS: EPSG:4326>
# Name: WGS 84
# Axis Info [ellipsoidal]:
# - Lat[north]: Geodetic latitude (degree)
# - Lon[east]: Geodetic longitude (degree)
# Area of Use:
# - name: World.
# - bounds: (-180.0, -90.0, 180.0, 90.0)
# Datum: World Geodetic System 1984 ensemble
# - Ellipsoid: WGS 84
# - Prime Meridian: Greenwich

# %%
municipality.shape
# Out:
# (775, 6)

# %%
municipality.plot()

# %%
municipality.boundary.plot()

# %%
municipality.plot(figsize=(10,10))

# %%
municipality.plot("PR_NAME",cmap='magma',legend=True)

# %%
import shapely

# %%
from shapely.geometry import Point , LineString , Polygon

# %%
#Create a geometric object
point = Point(1,1)
line = LineString([(0,0),(5,9),(10,8)])
poly = line.buffer(1)

# %%
point

# %%
line

# %%
poly

# %%
poly.contains(point)
# Out:
# True
